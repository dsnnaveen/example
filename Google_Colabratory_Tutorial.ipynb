# %% [markdown]
# <a href="https://colab.research.google.com/github/dsnnaveen/example/blob/master/Google_Colabratory_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2
# Out:
# 2

# %% [markdown]
# ## ***`[this is a Text](https:// [link text](https://))`***

# %% [markdown]
# # Upload data

# %% [markdown]
# Public link

# %%
# linux command in colab start with !
# to write any system label command start with ! it is excuted by the system
# !wget public link
# Out:
# --2022-04-18 01:03:25--  http://public/
# Resolving public (public)... failed: Name or service not known.
# wget: unable to resolve host address ‘public’
# --2022-04-18 01:03:25--  http://link/
# Resolving link (link)... failed: No address associated with hostname.
# wget: unable to resolve host address ‘link’

# %%
# !ls
# Out:
# sample_data

# %%
# !wget /content/sample_data/mnist_test.csv
# Out:
# /content/sample_data/mnist_test.csv: Scheme missing.

# %%
# !ls
# Out:
# sample_data

# %% [markdown]
# Google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Github Link

# %%
# !git clone git link

# %% [markdown]
# #Local drive

# %% [markdown]
# ## This *is* **heading**

# %% [markdown]
# ```
# # This is formatted as code
# for item in list:
#     print(item)
#
#
# ```

# %% [markdown]
# ![Screenshot (5).png](data:image/png;base64,...)

# %% [markdown]
# [Google Search](https://www.google.com)

# %% [markdown]
# first
# second
# third
#
#
# > Indented block
#
# 1.   List item
#
# *   List item
#
# > Indented block
#
#
# *   List item
#
#
# 2.   List item

# %% [markdown]
# 1.   First
# 2.   Second
#
#
# *   Third
# *   Four
#
#
#
# > my name is naveen and i started my life again

# %% [markdown]
# $$ x^2 $$
# $$ x1 = \frac{-b + \sqrt{b^2-4ac}}{2a}$$

# %% [markdown]
# $$ ax^2 + bx + c = 0 $$

# %% [markdown]
# $x1 = \frac{-b}{4aac}$
